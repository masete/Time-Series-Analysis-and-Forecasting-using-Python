# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics
import statsmodels as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA

# %%
df = pd.read_csv('Electric_Production.csv', 
                 index_col=0,parse_dates=True,squeeze=True)

# %%
df.head()
# Out:
# DATE
# 1985-01-01    72.5052
# 1985-02-01    70.6720
# 1985-03-01    62.4502
# 1985-04-01    57.4714
# 1985-05-01    55.3151
# Name: Value, dtype: float64

# %% [markdown]
# ##### we need to check if our data is stationary by plotting, stationary means data with some kind of pattern up and downward at a given line

# %%
plt.plot(df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### our data is stationary, but if it was not we would differentiate it once only not to affect the final results

# %%
df_diff1 =  df.diff().fillna(df)
plt.plot(df_diff1)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
we could apply a second round of difference but its not neceseryl 

e.g

df_diff2 =  df.diff().fillna(df)
plt.plot(df_diff1)
plt.show
